# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv('point-tables.csv')

# %%
data.head()
# Out:
#    year  point  games  correct  pct_correct
# 0  1997      1   1189      647     0.544155
# 1  1997      2   1189      641     0.539108
# 2  1997      3   1189      660     0.555088
# 3  1997      4   1189      674     0.566863
# 4  1997      5   1189      682     0.573591

# %%
plt.figure(figsize=(16,9))
d97 = data[data.year == 1997]
d18 = data[data.year == 2018]
plt.scatter(d97.point, d97.pct_correct)
plt.scatter(d18.point, d18.pct_correct)
plt.plot(d97.point, d97.pct_correct)
plt.plot(d18.point, d18.pct_correct)
