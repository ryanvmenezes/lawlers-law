# %%
import pandas as pd

# %%
game = pd.read_csv('../data/playbyplay/2018/0021700720.csv', dtype={'GAME_ID':str,'SCOREMARGIN':str})

# %%
game.head()
# Out:
#       GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0  0021700720         2            12                   0       1
# 1  0021700720         4            10                   0       1
# 2  0021700720         7             5                  40       1
# 3  0021700720         8             1                  58       1
# 4  0021700720        10             2                   5       1
#
#   WCTIMESTRING PCTIMESTRING  \
# 0      8:11 PM        12:00
# 1      8:11 PM        12:00
# 2      8:11 PM        11:50
# 3      8:11 PM        11:37
# 4      8:12 PM        11:12
#
#                                      HOMEDESCRIPTION  NEUTRALDESCRIPTION  \
# 0                                                NaN                 NaN
# 1        Jump Ball Davis vs. Capela: Tip to Anderson                 NaN
# 2                                                NaN                 NaN
# 3  Davis 6' Turnaround Hook Shot (2 PTS) (Holiday...                 NaN
# 4                                                NaN                 NaN
#
#                                 VISITORDESCRIPTION  SCORE SCOREMARGIN
# 0                                              NaN    NaN         NaN
# 1                                              NaN    NaN         NaN
# 2  Capela Out of Bounds Lost Ball Turnover (P1.T1)    NaN         NaN
# 3                                              NaN  0 - 2           2
# 4                             MISS Capela 2' Layup    NaN         NaN

# %%
g = game[(game.SCORE.notnull()) & (game.HOMEDESCRIPTION.notnull() | game.VISITORDESCRIPTION.notnull())]

# %%
g.head()
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 3   0021700720         8             1                  58       1
# 7   0021700720        13             1                   1       1
# 12  0021700720        20             1                   6       1
# 13  0021700720        21             1                 108       1
# 14  0021700720        23             1                 108       1
#
#    WCTIMESTRING PCTIMESTRING  \
# 3       8:11 PM        11:37
# 7       8:12 PM        10:54
# 12      8:13 PM        10:14
# 13      8:13 PM        10:01
# 14      8:13 PM         9:48
#
#                                       HOMEDESCRIPTION  NEUTRALDESCRIPTION  \
# 3   Davis 6' Turnaround Hook Shot (2 PTS) (Holiday...                 NaN
# 7         Holiday 20' Jump Shot (2 PTS) (Moore 1 AST)                 NaN
# 12                                                NaN                 NaN
# 13  Moore 1' Cutting Dunk Shot (2 PTS) (Cousins 1 ...                 NaN
# 14                                                NaN                 NaN
#
#                                 VISITORDESCRIPTION  SCORE SCOREMARGIN
# 3                                              NaN  0 - 2           2
# 7                                              NaN  0 - 4           4
# 12                 Harden 1' Driving Layup (2 PTS)  2 - 4           2
# 13                                             NaN  2 - 6           4
# 14  Capela  Cutting Dunk Shot (2 PTS) (Paul 1 AST)  4 - 6           2

# %%
g.to_csv('tmp.csv',)

# %%
def get_scoring_team(row):
    if row['HOMEDESCRIPTION'] == '':
        return 'HOME'
    if row['VISITORDESCRIPTION'] == '':
        return 'AWAY'
    return 'NULL'

# %%
def calculate_time(row):
    quarter = int(row['PERIOD'])
    minutes = int(row['PCTIMESTRING'].split(':')[0])
    seconds = int(row['PCTIMESTRING'].split(':')[1])
    return 2880 - (720)*(quarter - 1) - (11 - minutes)*(60) - (60 - seconds)

# %%
def process(df):
    g = df[
        (df.SCORE.notnull()) &
        (df.HOMEDESCRIPTION.notnull() | df.VISITORDESCRIPTION.notnull()) &
        (df.PERIOD <= 4)
    ].sort_values('EVENTNUM')
    
    g['TIME'] = g.apply(calculate_time, axis=1)
    
    g['AWAY'] = g['SCORE'].str.split(' - ').apply(lambda x: x[1])
    g['HOME'] = g['SCORE'].str.split(' - ').apply(lambda x: x[0])
    
    g['HOMEDESCRIPTION'].fillna('', inplace=True)
    g['VISITORDESCRIPTION'].fillna('', inplace=True)
    
    g['SCORINGTEAM'] = g.apply(get_scoring_team, axis=1)
    
    g['HOMEMARGIN'] = g['SCOREMARGIN'].apply(lambda x: int(x.replace('TIE','0')))
    
    return g#[['GAME_ID','EVENTNUM','PERIOD','TIME','AWAY','HOME','SCORINGTEAM','HOMEMARGIN','SCORE']]

# %%
pro = process(game)

# %%
pro.head()
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
#